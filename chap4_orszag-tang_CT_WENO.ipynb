# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# 4.5 計算例

# %% [markdown]
# 4.5.2 オルスザッグ・タングの渦問題 \
# 使用スキーム：HLLD法・WENO法・ホイン法・CT法

# %%
def minmod(x, y):
    return np.sign(x) * np.maximum(np.minimum(np.abs(x), np.sign(x) * y), 1e-20)


def WENO(q, axis):
    epsilon = 1e-6
    q0 = (2.0 * np.roll(q, 2, axis=axis) - 7.0 * np.roll(q, 1, axis=axis) + 11.0 * q) / 6.0
    q1 = (-np.roll(q, 1, axis=axis) + 5.0 * q + 2.0 * np.roll(q, -1, axis=axis)) / 6.0 
    q2 = (2.0 * q + 5.0 * np.roll(q, -1, axis=axis) - np.roll(q, -2, axis=axis)) / 6.0
    IS0 = 13.0/12.0 * (np.roll(q, 2, axis=axis) - 2.0 * np.roll(q, 1, axis=axis) + q)**2 \
        + 1.0/4.0 * (np.roll(q, 2, axis=axis) - 4.0 * np.roll(q, 1, axis=axis) + 3.0 * q)**2
    IS1 = 13.0/12.0 * (np.roll(q, 1, axis=axis) - 2.0 * q + np.roll(q, -1, axis=axis))**2 \
        + 1.0/4.0 * (np.roll(q, 1, axis=axis) - np.roll(q, -1, axis=axis))**2
    IS2 = 13.0/12.0 * (q - 2.0 * np.roll(q, -1, axis=axis) + np.roll(q, -2, axis=axis))**2 \
        + 1.0/4.0 * (3.0 * q - 4.0 * np.roll(q, -1, axis=axis) + np.roll(q, -2, axis=axis))**2
    a0 = 0.1 / (IS0 + epsilon)**2
    a1 = 0.6 / (IS1 + epsilon)**2
    a2 = 0.3 / (IS2 + epsilon)**2
    w0 = a0 / (a0 + a1 + a2)
    w1 = a1 / (a0 + a1 + a2)
    w2 = a2 / (a0 + a1 + a2)
    q_L = w0 * q0 + w1 * q1 + w2 * q2

    return q_L


def get_LR_component(rho, u, v, w, By, Bz, p, axis):
    rho_L = WENO(rho, axis)
    u_L = WENO(u, axis)
    v_L = WENO(v, axis)
    w_L = WENO(w, axis)
    By_L = WENO(By, axis)
    Bz_L = WENO(Bz, axis)
    p_L = WENO(p, axis)
    rho_R = np.roll(rho_L, -1, axis=axis)
    u_R = np.roll(u_L, -1, axis=axis)
    v_R = np.roll(v_L, -1, axis=axis)
    w_R = np.roll(w_L, -1, axis=axis)
    By_R = np.roll(By_L, -1, axis=axis)
    Bz_R = np.roll(Bz_L, -1, axis=axis)
    p_R = np.roll(p_L, -1, axis=axis)

    return rho_L, rho_R, u_L, u_R, v_L, v_R, w_L, w_R, By_L, By_R, Bz_L, Bz_R, p_L, p_R


def get_U_parameters_1(rho, u, v, w, Bx, By, Bz, e, pT, pT1, S, SM):
    rho1 = rho * (S - u) / (S - SM)
    u1 = SM
    v1 = v - Bx * By * (SM - u) / (rho * (S - u) * (S - SM) - Bx**2)
    w1 = w - Bx * Bz * (SM - u) / (rho * (S - u) * (S - SM) - Bx**2)
    By1 = By * (rho * (S - u)**2 - Bx**2) / (rho * (S - u) * (S - SM) - Bx**2)
    Bz1 = Bz * (rho * (S - u)**2 - Bx**2) / (rho * (S - u) * (S - SM) - Bx**2)
    e1 = ((S - u) * e - pT * u + pT1 * SM + Bx * ((u*Bx + v*By + w*Bz) - (u1*Bx + v1*By1 + w1*Bz1))) / (S - SM)
    
    return rho1, u1, v1, w1, By1, Bz1, e1


def get_U_parameters_2(rho1_L, rho1_R, u1_L, u1_R, v1_L, v1_R, w1_L, w1_R, Bx, By1_L, By1_R, Bz1_L, Bz1_R, e1_L, e1_R, SM):
    u2 = SM
    v2 = (np.sqrt(rho1_L) * v1_L + np.sqrt(rho1_R) * v1_R + (By1_R - By1_L) * np.sign(Bx)) / (np.sqrt(rho1_L) + np.sqrt(rho1_R))
    w2 = (np.sqrt(rho1_L) * w1_L + np.sqrt(rho1_R) * w1_R + (Bz1_R - Bz1_L) * np.sign(Bx)) / (np.sqrt(rho1_L) + np.sqrt(rho1_R))
    By2 = (np.sqrt(rho1_L) * By1_R + np.sqrt(rho1_R) * By1_L + np.sqrt(rho1_L * rho1_R) * (v1_R - v1_L) * np.sign(Bx)) / (np.sqrt(rho1_L) + np.sqrt(rho1_R))
    Bz2 = (np.sqrt(rho1_L) * Bz1_R + np.sqrt(rho1_R) * Bz1_L + np.sqrt(rho1_L * rho1_R) * (w1_R - w1_L) * np.sign(Bx)) / (np.sqrt(rho1_L) + np.sqrt(rho1_R))
    e2_L = e1_L - np.sqrt(rho1_L) * ((u1_L * Bx + v1_L * By1_L + w1_L * Bz1_L) - (u2 * Bx + v2 * By2 + w2 * Bz2)) * np.sign(Bx)
    e2_R = e1_R + np.sqrt(rho1_R) * ((u1_R * Bx + v1_R * By1_R + w1_R * Bz1_R) - (u2 * Bx + v2 * By2 + w2 * Bz2)) * np.sign(Bx)

    return u2, v2, w2, By2, Bz2, e2_L, e2_R


def get_flux(rho, u, v, w, Bx, By, Bz, e, pT, F):
    F[0, :, :] = rho * u
    F[1, :, :] = rho * u**2 + pT - Bx**2
    F[2, :, :] = rho * u * v - Bx * By
    F[3, :, :] = rho * u * w - Bx * Bz
    F[4, :, :] = 0.0
    F[5, :, :] = u * By - v * Bx
    F[6, :, :] = u * Bz - w * Bx
    F[7, :, :] = (e + pT) * u - Bx * (Bx * u + By * v + Bz * w)
    return F


def get_flux_HLLD(rho, u, v, w, Bx, By, Bz, e, gamma, F, axis):

    # 半整数格子点上のものを使わないといけない。1次元だと関係なかったけど。
    Bx_half = 0.5 * (Bx + np.roll(Bx, -1, axis=axis))

    p = (gamma - 1.0) * (e - rho * 0.5 * (u**2 + v**2 + w**2) - 0.5 * (Bx**2 + By**2 + Bz**2))
    # eではなくp(ガス圧)を補間。これで流速が大きいときでも対応できた
    rho_L, rho_R, u_L, u_R, v_L, v_R, w_L, w_R, By_L, By_R, Bz_L, Bz_R, p_L, p_R = get_LR_component(rho, u, v, w, By, Bz, p, axis)
    pT_L = p_L + 0.5 * (Bx_half**2 + By_L**2 + Bz_L**2)
    pT_R = p_R + 0.5 * (Bx_half**2 + By_R**2 + Bz_R**2)
    e_L = p_L / (gamma - 1.0) + rho_L * 0.5 * (u_L**2 + v_L**2 + w_L**2) + 0.5 * (Bx_half**2 + By_L**2 + Bz_L**2)
    e_R = p_R / (gamma - 1.0) + rho_R * 0.5 * (u_R**2 + v_R**2 + w_R**2) + 0.5 * (Bx_half**2 + By_R**2 + Bz_R**2)
    cs_L = np.sqrt(gamma * p_L / rho_L)
    cs_R = np.sqrt(gamma * p_R / rho_R)
    ca_L = np.sqrt((Bx_half**2 + By_L**2 + Bz_L**2) / rho_L)
    ca_R = np.sqrt((Bx_half**2 + By_R**2 + Bz_R**2) / rho_R)
    va_L = np.sqrt(Bx_half**2 / rho_L)
    va_R = np.sqrt(Bx_half**2 / rho_R)
    cf_L = np.sqrt(0.5 * (cs_L**2 + ca_L**2 + np.sqrt((cs_L**2 + ca_L**2)**2 - 4.0 * cs_L**2 * va_L**2)))
    cf_R = np.sqrt(0.5 * (cs_R**2 + ca_R**2 + np.sqrt((cs_R**2 + ca_R**2)**2 - 4.0 * cs_R**2 * va_R**2)))
    S_L = np.minimum(u_L - cf_L, u_R - cf_R)
    S_R = np.maximum(u_L + cf_L, u_R + cf_R)
    #S_L = np.minimum(S_L, 0.0)
    #S_R = np.maximum(S_R, 0.0)

    SM = ((S_R - u_R) * rho_R * u_R - (S_L - u_L) * rho_L * u_L - pT_R + pT_L) / ((S_R - u_R) * rho_R - (S_L - u_L) * rho_L)
    pT1 = ((S_R - u_R) * rho_R * pT_L - (S_L - u_L) * rho_L * pT_R + rho_L * rho_R * (S_R - u_R) * (S_L - u_L) * (u_R - u_L)) / ((S_R - u_R) * rho_R - (S_L - u_L) * rho_L)
    pT1_L = pT1
    pT1_R = pT1
    rho1_L, u1_L, v1_L, w1_L, By1_L, Bz1_L, e1_L = get_U_parameters_1(rho_L, u_L, v_L, w_L, Bx_half, By_L, Bz_L, e_L, pT_L, pT1_L, S_L, SM)
    rho1_R, u1_R, v1_R, w1_R, By1_R, Bz1_R, e1_R = get_U_parameters_1(rho_R, u_R, v_R, w_R, Bx_half, By_R, Bz_R, e_R, pT_R, pT1_R, S_R, SM)

    S1_L = SM - np.sqrt(Bx_half**2 / rho1_L)
    S1_R = SM + np.sqrt(Bx_half**2 / rho1_R)

    u2, v2, w2, By2, Bz2, e2_L, e2_R = get_U_parameters_2(rho1_L, rho1_R, u1_L, u1_R, v1_L, v1_R, w1_L, w1_R, Bx_half, By1_L, By1_R, Bz1_L, Bz1_R, e1_L, e1_R, SM)
    pT2_L = pT1
    pT2_R = pT1
    rho2_L = rho1_L
    rho2_R = rho1_R

    # Fの選択
    F_L = np.zeros(F.shape)
    F1_L = np.zeros(F.shape)
    F2_L = np.zeros(F.shape)
    F_R = np.zeros(F.shape)
    F1_R = np.zeros(F.shape)
    F2_R = np.zeros(F.shape)
    F_L = get_flux(rho_L, u_L, v_L, w_L, Bx_half, By_L, Bz_L, e_L, pT_L, F_L)
    F1_L = get_flux(rho1_L, u1_L, v1_L, w1_L, Bx_half, By1_L, Bz1_L, e1_L, pT1_L, F1_L)
    F2_L = get_flux(rho2_L, u2, v2, w2, Bx_half, By2, Bz2, e2_L, pT2_L, F2_L)
    F_R = get_flux(rho_R, u_R, v_R, w_R, Bx_half, By_R, Bz_R, e_R, pT_R, F_R)
    F1_R = get_flux(rho1_R, u1_R, v1_R, w1_R, Bx_half, By1_R, Bz1_R, e1_R, pT1_R, F1_R)
    F2_R = get_flux(rho2_R, u2, v2, w2, Bx_half, By2, Bz2, e2_R, pT2_R, F2_R)

    F = F_L * (S_L > 0.0) + F1_L * ((S_L <= 0.0) & (0.0 < S1_L)) + F2_L * ((S1_L <= 0.0) & (0.0 < SM)) \
      + F_R * (S_R <= 0.0) + F1_R * ((S1_R <= 0.0) & (0.0 < S_R)) + F2_R * ((SM <= 0.0) & (0.0 < S1_R))

    return F    


def divB_cleaner_CT(Bx_old, By_old, Ez_F, Ez_G, dx, dy, dt, U):
    
    Ez = 0.25 * (Ez_G + np.roll(Ez_G, -1, axis=0) + Ez_F + np.roll(Ez_F, -1, axis=1))
    U[4, :, :] = Bx_old - dt/dy * (Ez - np.roll(Ez, 1, axis=1))
    U[5, :, :] = By_old + dt/dx * (Ez - np.roll(Ez, 1, axis=0))

    return U

# %%
nx = 256
ny = 256
x_max = 2 * np.pi 
y_max = 2 * np.pi
dx = x_max / nx
dy = y_max / ny
dt = 0.0
CFL = 0.7
x = np.arange(0.0, x_max, dx)
y = np.arange(0.0, y_max, dy)
X, Y = np.meshgrid(x, y)

gamma = 5.0/3.0

U = np.zeros([8, x.shape[0], y.shape[0]]) # rho, rho*u, rho*v, rho*w, Bx, By, Bz, e
# ここでのLとRはメインループ内のL・Rの意味とは違う
# ここのは左半分・右半分の意味
rho_init = gamma**2
u_init = -np.sin(Y).T
v_init = np.sin(X).T
w_init = 0.0
Bx_init = -np.sin(Y).T
By_init = np.sin(2*X).T
Bz_init = 0.0
p_init = gamma
U[0, :, :] = rho_init
U[1, :, :] = rho_init * u_init
U[2, :, :] = rho_init * v_init
U[3, :, :] = rho_init * w_init
U[4, :, :] = Bx_init
U[5, :, :] = By_init
U[6, :, :] = Bz_init
U[7, :, :] = p_init/(gamma-1) + rho_init * (u_init**2 + v_init**2 + w_init**2)/2 + (Bx_init**2 + By_init**2 + Bz_init**2)/2

F = np.zeros(U.shape)
F_bar = np.zeros(F.shape)
G = np.zeros(U.shape)
G_bar = np.zeros(G.shape)

# %%
max_step = 10000
time = 0.0
calculation_time = 10.0
log_filename = "log_CT_WENO.txt"
np.save(f"results_orszag-tang_CT_WENO/U_{0}.npy", U)
with open(log_filename, 'w') as log_file:
    log_file.write(f"{0},{time:.5f},{dt:.5f}\n")

for t in range(1, max_step+1):
    if (t % 10 == 0):
        print(f"{t} step done... : dt = {dt:.5f}")
        np.save(f"results_orszag-tang_CT_WENO/U_{t}.npy", U)
        with open(log_filename, 'a') as log_file:
            log_file.write(f"{t},{time:.5f},{dt:.5f}\n")

    if time > calculation_time:
        print(f"{t} steps (t = {time:.3f}) : Calculation is stopped")
        break

    
    U_bar = U.copy()
    Bx_old = U[4, :, :].copy()
    By_old = U[5, :, :].copy()

    rho = U[0, :, :]
    u = U[1, :, :] / rho
    v = U[2, :, :] / rho
    w = U[3, :, :] / rho
    Bx = U[4, :, :]
    By = U[5, :, :]
    Bz = U[6, :, :]
    e = U[7, :, :]
    p = (gamma - 1.0) * (e - 0.5 * rho * (u**2+v**2+w**2) - 0.5 * (Bx**2+By**2+Bz**2))
    #print(np.abs(Bx - np.roll(Bx, 1, axis=0) + By - np.roll(By, 1, axis=1)).sum())
    # CT法で新たに追加されたところ
    Bx = 0.5 * (Bx + np.roll(Bx, 1, axis=0))
    By = 0.5 * (By + np.roll(By, 1, axis=1))

    F = get_flux_HLLD(rho, u, v, w, Bx, By, Bz, e, gamma, F, axis=0)
    G = get_flux_HLLD(rho, v, w, u, By, Bz, Bx, e, gamma, G, axis=1)
    G_tmp = G.copy()
    G[1, :, :] = G_tmp[3, :, :]
    G[2, :, :] = G_tmp[1, :, :]
    G[3, :, :] = G_tmp[2, :, :]
    G[4, :, :] = G_tmp[6, :, :]
    G[5, :, :] = G_tmp[4, :, :]
    G[6, :, :] = G_tmp[5, :, :]

    cs = np.sqrt(gamma * p / rho)
    ca = np.sqrt((Bx**2 + By**2 + Bz**2) / rho)
    dt = CFL * np.min(1.0 / ((np.abs(u) + np.sqrt(cs**2 + ca**2)) / dx + (np.abs(v) + np.sqrt(cs**2 + ca**2)) / dy))
    
    U_bar += -dt/dx * (F - np.roll(F, 1, axis=1)) - dt/dy * (G - np.roll(G, 1, axis=2))
    # CT法で新たに追加されたところ
    Ez_F = F[5, :, :] * (-1)
    Ez_G = G[4, :, :]
    U_bar = divB_cleaner_CT(Bx_old, By_old, Ez_F, Ez_G, dx, dy, dt, U_bar)

    rho = U_bar[0, :, :]
    u = U_bar[1, :, :] / rho
    v = U_bar[2, :, :] / rho
    w = U_bar[3, :, :] / rho
    Bx = U_bar[4, :, :]
    By = U_bar[5, :, :]
    Bz = U_bar[6, :, :]
    e = U_bar[7, :, :]
    p = (gamma - 1.0) * (e - 0.5 * rho * (u**2 + v**2 + w**2) - 0.5 * (Bx**2 + By**2 + Bz**2))
    # CT法で新たに追加されたところ
    Bx = 0.5 * (Bx + np.roll(Bx, 1, axis=0))
    By = 0.5 * (By + np.roll(By, 1, axis=1))

    F_bar = get_flux_HLLD(rho, u, v, w, Bx, By, Bz, e, gamma, F_bar, axis=0)
    G_bar = get_flux_HLLD(rho, v, w, u, By, Bz, Bx, e, gamma, G_bar, axis=1)
    G_tmp = G_bar.copy()
    G_bar[1, :, :] = G_tmp[3, :, :]
    G_bar[2, :, :] = G_tmp[1, :, :]
    G_bar[3, :, :] = G_tmp[2, :, :]
    G_bar[4, :, :] = G_tmp[6, :, :]
    G_bar[5, :, :] = G_tmp[4, :, :]
    G_bar[6, :, :] = G_tmp[5, :, :]

    F = 0.5 * (F + F_bar)
    G = 0.5 * (G + G_bar)

    U += -dt/dx * (F - np.roll(F, 1, axis=1)) - dt/dy * (G - np.roll(G, 1, axis=2))
    # CT法で新たに追加されたところ
    # Ez_F, Ez_Gはタイムステップがnのものを使うらしいので、ここではEz_F, Ez_Gを求めないことにする
    U = divB_cleaner_CT(Bx_old, By_old, Ez_F, Ez_G, dx, dy, dt, U)

    time += dt
# Out:
# 10 step done... : dt = 0.00388
# 20 step done... : dt = 0.00386
# 30 step done... : dt = 0.00385
# 40 step done... : dt = 0.00383
# 50 step done... : dt = 0.00381
# 60 step done... : dt = 0.00380
# 70 step done... : dt = 0.00379
# 80 step done... : dt = 0.00378
# 90 step done... : dt = 0.00377
# 100 step done... : dt = 0.00376
# 110 step done... : dt = 0.00376
# 120 step done... : dt = 0.00375
# 130 step done... : dt = 0.00375
# 140 step done... : dt = 0.00374
# 150 step done... : dt = 0.00374
# 160 step done... : dt = 0.00374
# 170 step done... : dt = 0.00375
# 180 step done... : dt = 0.00375
# 190 step done... : dt = 0.00376
# 200 step done... : dt = 0.00377
# 210 step done... : dt = 0.00378
# 220 step done... : dt = 0.00379
# 230 step done... : dt = 0.00377
# 240 step done... : dt = 0.00373
# 250 step done... : dt = 0.00368
# 260 step done... : dt = 0.00365
# 270 step done... : dt = 0.00361
# 280 step done... : dt = 0.00359
# 290 step done... : dt = 0.00357
# 300 step done... : dt = 0.00355
# 310 step done... : dt = 0.00354
# 320 step done... : dt = 0.00353
# 330 step done... : dt = 0.00353
# 340 step done... : dt = 0.00353
# 350 step done... : dt = 0.00353
# 360 step done... : dt = 0.00353
# 370 step done... : dt = 0.00354
# 380 step done... : dt = 0.00354
# 390 step done... : dt = 0.00355
# 400 step done... : dt = 0.00356
# 410 step done... : dt = 0.00356
# 420 step done... : dt = 0.00357
# 430 step done... : dt = 0.00358
# 440 step done... : dt = 0.00359
# 450 step done... : dt = 0.00360
# 460 step done... : dt = 0.00361
# 470 step done... : dt = 0.00362
# 480 step done... : dt = 0.00363
# 490 step done... : dt = 0.00364
# 500 step done... : dt = 0.00365
# 510 step done... : dt = 0.00366
# 520 step done... : dt = 0.00367
# 530 step done... : dt = 0.00368
# 540 step done... : dt = 0.00369
# 550 step done... : dt = 0.00371
# 560 step done... : dt = 0.00372
# 570 step done... : dt = 0.00373
# 580 step done... : dt = 0.00375
# 590 step done... : dt = 0.00377
# 600 step done... : dt = 0.00380
# 610 step done... : dt = 0.00382
# 620 step done... : dt = 0.00384
# 630 step done... : dt = 0.00386
# 640 step done... : dt = 0.00388
# 650 step done... : dt = 0.00389
# 660 step done... : dt = 0.00388
# 670 step done... : dt = 0.00388
# 680 step done... : dt = 0.00378
# 690 step done... : dt = 0.00372
# 700 step done... : dt = 0.00370
# 710 step done... : dt = 0.00369
# 720 step done... : dt = 0.00369
# 730 step done... : dt = 0.00369
# 740 step done... : dt = 0.00369
# 750 step done... : dt = 0.00369
# 760 step done... : dt = 0.00369
# 770 step done... : dt = 0.00369
# 780 step done... : dt = 0.00370
# 790 step done... : dt = 0.00372
# 800 step done... : dt = 0.00375
# 810 step done... : dt = 0.00377
# 820 step done... : dt = 0.00380
# 830 step done... : dt = 0.00383
# 840 step done... : dt = 0.00385
# 850 step done... : dt = 0.00385
# 860 step done... : dt = 0.00384
# 870 step done... : dt = 0.00384
# 880 step done... : dt = 0.00383
# 890 step done... : dt = 0.00383
# 900 step done... : dt = 0.00382
# 910 step done... : dt = 0.00382
# 920 step done... : dt = 0.00380
# 930 step done... : dt = 0.00376
# 940 step done... : dt = 0.00375
# 950 step done... : dt = 0.00374
# 960 step done... : dt = 0.00373
# 970 step done... : dt = 0.00372
# 980 step done... : dt = 0.00371
# 990 step done... : dt = 0.00370
# 1000 step done... : dt = 0.00369
# 1010 step done... : dt = 0.00369
# 1020 step done... : dt = 0.00368
# 1030 step done... : dt = 0.00368
# 1040 step done... : dt = 0.00367
# 1050 step done... : dt = 0.00362
# 1060 step done... : dt = 0.00358
# 1070 step done... : dt = 0.00356
# 1080 step done... : dt = 0.00353
# 1090 step done... : dt = 0.00352
# 1100 step done... : dt = 0.00347
# 1110 step done... : dt = 0.00346
# 1120 step done... : dt = 0.00347
# 1130 step done... : dt = 0.00349
# 1140 step done... : dt = 0.00350
# 1150 step done... : dt = 0.00350
# 1160 step done... : dt = 0.00343
# 1170 step done... : dt = 0.00336
# 1180 step done... : dt = 0.00330
# 1190 step done... : dt = 0.00326
# 1200 step done... : dt = 0.00322
# 1210 step done... : dt = 0.00320
# 1220 step done... : dt = 0.00322
# 1230 step done... : dt = 0.00326
# 1240 step done... : dt = 0.00327
# 1250 step done... : dt = 0.00330
# 1260 step done... : dt = 0.00335
# 1270 step done... : dt = 0.00336
# 1280 step done... : dt = 0.00340
# 1290 step done... : dt = 0.00340
# 1300 step done... : dt = 0.00340
# 1310 step done... : dt = 0.00340
# 1320 step done... : dt = 0.00341
# 1330 step done... : dt = 0.00341
# 1340 step done... : dt = 0.00341
# 1350 step done... : dt = 0.00341
# 1360 step done... : dt = 0.00340
# 1370 step done... : dt = 0.00340
# 1380 step done... : dt = 0.00341
# 1390 step done... : dt = 0.00341
# 1400 step done... : dt = 0.00342
# 1410 step done... : dt = 0.00342
# 1420 step done... : dt = 0.00343
# 1430 step done... : dt = 0.00343
# 1440 step done... : dt = 0.00344
# 1450 step done... : dt = 0.00345
# 1460 step done... : dt = 0.00346
# 1470 step done... : dt = 0.00346
# 1480 step done... : dt = 0.00346
# 1490 step done... : dt = 0.00346
# 1500 step done... : dt = 0.00346
# 1510 step done... : dt = 0.00345
# 1520 step done... : dt = 0.00344
# 1530 step done... : dt = 0.00343
# 1540 step done... : dt = 0.00343
# 1550 step done... : dt = 0.00342
# 1560 step done... : dt = 0.00341
# 1570 step done... : dt = 0.00341
# 1580 step done... : dt = 0.00340
# 1590 step done... : dt = 0.00339
# 1600 step done... : dt = 0.00339
# 1610 step done... : dt = 0.00338
# 1620 step done... : dt = 0.00338
# 1630 step done... : dt = 0.00337
# 1640 step done... : dt = 0.00337
# 1650 step done... : dt = 0.00336
# 1660 step done... : dt = 0.00335
# 1670 step done... : dt = 0.00335
# 1680 step done... : dt = 0.00335
# 1690 step done... : dt = 0.00334
# 1700 step done... : dt = 0.00334
# 1710 step done... : dt = 0.00334
# 1720 step done... : dt = 0.00334
# 1730 step done... : dt = 0.00335
# 1740 step done... : dt = 0.00335
# 1750 step done... : dt = 0.00335
# 1760 step done... : dt = 0.00335
# 1770 step done... : dt = 0.00335
# 1780 step done... : dt = 0.00333
# 1790 step done... : dt = 0.00332
# 1800 step done... : dt = 0.00333
# 1810 step done... : dt = 0.00334
# 1820 step done... : dt = 0.00335
# 1830 step done... : dt = 0.00336
# 1840 step done... : dt = 0.00337
# 1850 step done... : dt = 0.00337
# 1860 step done... : dt = 0.00338
# 1870 step done... : dt = 0.00339
# 1880 step done... : dt = 0.00339
# 1890 step done... : dt = 0.00339
# 1900 step done... : dt = 0.00340
# 1910 step done... : dt = 0.00340
# 1920 step done... : dt = 0.00341
# 1930 step done... : dt = 0.00341
# 1940 step done... : dt = 0.00341
# 1950 step done... : dt = 0.00342
# 1960 step done... : dt = 0.00342
# 1970 step done... : dt = 0.00343
# 1980 step done... : dt = 0.00344
# 1990 step done... : dt = 0.00343
# 2000 step done... : dt = 0.00342
# 2010 step done... : dt = 0.00341
# 2020 step done... : dt = 0.00340
# 2030 step done... : dt = 0.00339
# 2040 step done... : dt = 0.00338
# 2050 step done... : dt = 0.00338
# 2060 step done... : dt = 0.00338
# 2070 step done... : dt = 0.00338
# 2080 step done... : dt = 0.00338
# 2090 step done... : dt = 0.00338
# 2100 step done... : dt = 0.00339
# 2110 step done... : dt = 0.00339
# 2120 step done... : dt = 0.00339
# 2130 step done... : dt = 0.00340
# 2140 step done... : dt = 0.00336
# 2150 step done... : dt = 0.00333
# 2160 step done... : dt = 0.00332
# 2170 step done... : dt = 0.00332
# 2180 step done... : dt = 0.00332
# 2190 step done... : dt = 0.00332
# 2200 step done... : dt = 0.00332
# 2210 step done... : dt = 0.00331
# 2220 step done... : dt = 0.00331
# 2230 step done... : dt = 0.00331
# 2240 step done... : dt = 0.00331
# 2250 step done... : dt = 0.00331
# 2260 step done... : dt = 0.00331
# 2270 step done... : dt = 0.00331
# 2280 step done... : dt = 0.00330
# 2290 step done... : dt = 0.00330
# 2300 step done... : dt = 0.00330
# 2310 step done... : dt = 0.00330
# 2320 step done... : dt = 0.00329
# 2330 step done... : dt = 0.00328
# 2340 step done... : dt = 0.00328
# 2350 step done... : dt = 0.00327
# 2360 step done... : dt = 0.00327
# 2370 step done... : dt = 0.00327
# 2380 step done... : dt = 0.00327
# 2390 step done... : dt = 0.00326
# 2400 step done... : dt = 0.00324
# 2410 step done... : dt = 0.00324
# 2420 step done... : dt = 0.00324
# 2430 step done... : dt = 0.00325
# 2440 step done... : dt = 0.00326
# 2450 step done... : dt = 0.00328
# 2460 step done... : dt = 0.00329
# 2470 step done... : dt = 0.00331
# 2480 step done... : dt = 0.00333
# 2490 step done... : dt = 0.00335
# 2500 step done... : dt = 0.00337
# 2510 step done... : dt = 0.00339
# 2520 step done... : dt = 0.00342
# 2530 step done... : dt = 0.00344
# 2540 step done... : dt = 0.00347
# 2550 step done... : dt = 0.00349
# 2560 step done... : dt = 0.00351
# 2570 step done... : dt = 0.00353
# 2580 step done... : dt = 0.00354
# 2590 step done... : dt = 0.00356
# 2600 step done... : dt = 0.00357
# 2610 step done... : dt = 0.00356
# 2620 step done... : dt = 0.00356
# 2630 step done... : dt = 0.00356
# 2640 step done... : dt = 0.00356
# 2650 step done... : dt = 0.00357
# 2660 step done... : dt = 0.00357
# 2670 step done... : dt = 0.00358
# 2680 step done... : dt = 0.00359
# 2690 step done... : dt = 0.00359
# 2700 step done... : dt = 0.00360
# 2710 step done... : dt = 0.00362
# 2720 step done... : dt = 0.00363
# 2730 step done... : dt = 0.00365
# 2740 step done... : dt = 0.00367
# 2750 step done... : dt = 0.00367
# 2760 step done... : dt = 0.00368
# 2770 step done... : dt = 0.00368
# 2780 step done... : dt = 0.00369
# 2790 step done... : dt = 0.00369
# 2800 step done... : dt = 0.00370
# 2810 step done... : dt = 0.00371
# 2820 step done... : dt = 0.00372
# 2830 step done... : dt = 0.00374
# 2838 steps (t = 10.000) : Calculation is stopped

# %%
fig = plt.figure(figsize=(8, 6))
ax1 = fig.add_subplot(111)

log = np.loadtxt("log_CT_WENO.txt", delimiter=',')
step = 2500
U = np.load(f"results_orszag-tang_CT_WENO/U_{step}.npy")
rho = U[0, :, :]
u = U[1, :, :] / rho
v = U[2, :, :] / rho
w = U[3, :, :] / rho
Bx = U[4, :, :]
By = U[5, :, :]
Bz = U[6, :, :]
e = U[7, :, :]
p = (gamma-1) * (e - rho*(u**2+v**2+w**2)/2 - (Bx**2+By**2+Bz**2)/2)
magnetic_pressure = 1/2 * (Bx**2+By**2+Bz**2)
pT = p + magnetic_pressure

contour = ax1.pcolormesh(X, Y, (p/rho).T, vmin=0.3, vmax=1.3, cmap='jet')
cbar = plt.colorbar(contour, ax=ax1)

ax1.set_title(r"$p/\rho$", fontsize=24)
ax1.text(0.8, 1.02, f"t = {log[int(step/10)][1]:.3f}", transform=ax1.transAxes, fontsize=16)
ax1.tick_params(labelsize=16)
plt.show()

# %%
fig = plt.figure(figsize=(8, 6))
ax1 = fig.add_subplot(111)

log = np.loadtxt("log_CT_WENO.txt", delimiter=',')
total_steps = int(log[-1][0])
interval = 10
for step in range(0, total_steps+interval, interval):
    ax1.clear()

    U = np.load(f"results_orszag-tang_CT_WENO/U_{step}.npy")
    rho = U[0, :, :]
    u = U[1, :, :] / rho 
    v = U[2, :, :] / rho 
    w = U[3, :, :] / rho 
    Bx = U[4, :, :]
    By = U[5, :, :]
    Bz = U[6, :, :]
    e = U[7, :, :]
    p = (gamma-1) * (e - rho*(u**2+v**2+w**2)/2 - (Bx**2+By**2+Bz**2)/2)
    magnetic_pressure = 1/2 * (Bx**2+By**2+Bz**2)
    pT = p + magnetic_pressure

    #contour = ax1.pcolormesh(X, Y, (rho).T, vmin=2.0, vmax=5.0, cmap='jet')
    #contour = ax1.pcolormesh(X, Y, (magnetic_pressure).T, vmin=0.0, vmax=3.0, cmap='jet')
    contour = ax1.pcolormesh(X, Y, (p/rho).T, vmin=0.3, vmax=1.3, cmap='jet')
    if step == 0:
        cbar = plt.colorbar(contour, ax=ax1)

    ax1.set_title(r"$p/\rho$", fontsize=24)
    ax1.text(0.8, 1.02, f"t = {log[int(step/10)][1]:.3f}", transform=ax1.transAxes, fontsize=16)
    ax1.tick_params(labelsize=16)

    fig.savefig(f"pictures_CT_WENO/{step}.png", dpi=200)


filename = "orszag-tang_p-rho_CT_WENO.mp4"
img = cv2.imread(f'./pictures_CT_WENO/0.png')
framesize = (img.shape[1], img.shape[0])
fps = 10.0
fourcc = cv2.VideoWriter_fourcc('m','p','4','v')
video  = cv2.VideoWriter(filename=filename, fourcc=fourcc, fps=fps, frameSize=framesize)

for step in range(0, total_steps+interval, interval):
    img = cv2.imread(f'./pictures_CT_WENO/{step}.png')
    video.write(img)
video.release()
